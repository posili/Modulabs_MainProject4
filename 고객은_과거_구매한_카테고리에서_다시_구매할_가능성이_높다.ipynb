# %% [markdown]
# <a href="https://colab.research.google.com/github/posili/Modulabs_MainProject4/blob/master/%EA%B3%A0%EA%B0%9D%EC%9D%80_%EA%B3%BC%EA%B1%B0_%EA%B5%AC%EB%A7%A4%ED%95%9C_%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC%EC%97%90%EC%84%9C_%EB%8B%A4%EC%8B%9C_%EA%B5%AC%EB%A7%A4%ED%95%A0_%EA%B0%80%EB%8A%A5%EC%84%B1%EC%9D%B4_%EB%86%92%EB%8B%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 서희님과 동일한 테이블을 사용하므로 해당 데이터셋 병합 과정은 생략

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Brazilian E-Commerce Public Dataset/eng_ver.csv')

#원본 백업
df_origin = df.copy()

# %%
#전체 컬럼 보기 설정
pd.set_option('display.max_columns', None)
#필수 컬럼만 남김
df = df[['order_id', 'customer_unique_id', 'product_id', 'order_item_id', 'product_category_name_english']]
#컬럼명 변경
df['product_category_name'] = df['product_category_name_english']

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113425 entries, 0 to 113424
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       113425 non-null  object
#  1   customer_unique_id             113425 non-null  object
#  2   product_id                     112650 non-null  object
#  3   order_item_id                  112650 non-null  float64
#  4   product_category_name_english  111023 non-null  object
#  5   product_category_name          111023 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# ## 결측치

# %%
df.isna().sum()
# Out:
# order_id                            0
# customer_unique_id                  0
# product_id                        775
# order_item_id                     775
# product_category_name_english    2402
# product_category_name            2402
# dtype: int64

# %%
df.isna().mean()
# Out:
# order_id                         0.000000
# customer_unique_id               0.000000
# product_id                       0.006833
# order_item_id                    0.006833
# product_category_name_english    0.021177
# product_category_name            0.021177
# dtype: float64

# %%
df[df['product_category_name'].isna()]
# Out:
#                                 order_id                customer_unique_id  \
# 7       1093c8304c7a003280dd34598194913d  57b2a98a409812fe9618067b6b8ebe4f
# 50      6e98de3a85c84ead6689189b825d35b5  233896de79986082f1f479f1f85281cb
# 90      cc07a8fdd3a8e94d683c8142a117dbc1  e5dbefdfdf3eff75c8e6cd655f128279
# 174     f51e3c7f79d1e2c076acbb6af1588b95  755bdc2822a8f01cfcec19ae4dcaae66
# 330     df8c077268f7f3baaac0892eb3143642  0071f46a072a9ae25bbe4438b15efe9c
# ...                                  ...                               ...
# 113045  9b932dca249f9971b86dde2f2d7ad412  639b4096a4e5c96549a9bb495ca4871e
# 113091  d08257023bba46fdf7e3cfcccac606b8  74ec77145a467b1a96152aac1c3ab137
# 113092  d08257023bba46fdf7e3cfcccac606b8  74ec77145a467b1a96152aac1c3ab137
# 113184  a1fa82769a203e30b8faf81cd32e5193  6d443b75cff956bb73dce7385033e266
# 113294  5f95f5f78f509a3af5a6c83d81c1117f  8adff52976579b096284ce43e65d6160
#
#                               product_id  order_item_id  \
# 7       124f74f703e88efe001a10bfa718b6ff            1.0
# 50                                   NaN            NaN
# 90      5a848e4ab52fd5445cdc07aab1c40e48            1.0
# 174     e1da02256dce4dee2207c36853547c7b            1.0
# 330                                  NaN            NaN
# ...                                  ...            ...
# 113045                               NaN            NaN
# 113091  cf951c39ef0ca44ee11278e4ece167d1            1.0
# 113092  cf951c39ef0ca44ee11278e4ece167d1            2.0
# 113184  24aba57735be13fd785bc04d1a8812e4            2.0
# 113294  2b7f2a7cf1025b94bc5dc6c28746beaf            1.0
#
#        product_category_name_english product_category_name
# 7                                NaN                   NaN
# 50                               NaN                   NaN
# 90                               NaN                   NaN
# 174                              NaN                   NaN
# 330                              NaN                   NaN
# ...                              ...                   ...
# 113045                           NaN                   NaN
# 113091                           NaN                   NaN
# 113092                           NaN                   NaN
# 113184                           NaN                   NaN
# 113294                           NaN                   NaN
#
# [2402 rows x 6 columns]

# %% [markdown]
# ### 임의로 채우면 오히려 노이즈가 발생할 확률이 높다고 판단, 제거해도 치명적인 데이터 양이 아니라 drop 결정

# %%
product_category_name_nan = df[df['product_category_name'].isna()].index
product_id_nan = df[df['product_id'].isna()].index
order_item_id_nan = df[df['order_item_id'].isna()].index

# %%
len(df)
# Out:
# 113425

# %%
df.dropna()
# Out:
#                                 order_id                customer_unique_id  \
# 0       00e7ee1b050b8499577073aeb2a297a1  861eff4711a542e4b93843c6dd7febb0
# 1       29150127e6685892b6eab3eec79f59c7  290c77bc529b7ac935b93aa66c333dc3
# 2       b2059ed67ce144a36e2aa97d2c9e9ad2  060e732b5b29e8181a18229c7b0b2b5e
# 3       951670f92359f4fe4a63112aa7306eba  259dac757896d24d7702b9acbbff3f3c
# 4       6b7d50bd145f6fc7f33cebabd7e49d0f  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 113420  6760e20addcf0121e9d58f2f1ff14298  1a29b476fee25c95fbafc67c5ac95cf8
# 113421  9ec0c8947d973db4f4e8dcf1fbfa8f1b  d52a67c98be1cf6a5c84435bd38d095d
# 113422  fed4434add09a6f332ea398efd656a5c  e9f50caf99f032f0bf3c55141f019d99
# 113423  e31ec91cea1ecf97797787471f98a8c2  73c2643a0a458b49f58cea58833b192e
# 113424  28db69209a75e59f20ccbb5c36a20b90  84732c5050c01db9b23e19ba39899398
#
#                               product_id  order_item_id  \
# 0       a9516a079e37a9c9c36b9b78b10169e8            1.0
# 1       4aa6014eceb682077f9dc4bffebc05b0            1.0
# 2       bd07b66896d6f1494f5b86251848ced7            1.0
# 3       a5647c44af977b148e0a3a4751a09e2e            1.0
# 4       9391a573abe00141c56e38d84d7d5b3b            1.0
# ...                                  ...            ...
# 113420  ccb4503d9d43d245d3b295d0544f988b            1.0
# 113421  9ede6b0570a75a4b9de4f383329f99ee            1.0
# 113422  7a5d2e1e131a860ae7d18f6fffa9d689            1.0
# 113423  f819f0c84a64f02d3a5606ca95edd272            1.0
# 113424  017692475c1c954ff597feda05131d73            1.0
#
#        product_category_name_english   product_category_name
# 0                   office_furniture        office_furniture
# 1                         housewares              housewares
# 2                   office_furniture        office_furniture
# 3                   office_furniture        office_furniture
# 4                       home_confort            home_confort
# ...                              ...                     ...
# 113420        books_general_interest  books_general_interest
# 113421                sports_leisure          sports_leisure
# 113422                 health_beauty           health_beauty
# 113423                 watches_gifts           watches_gifts
# 113424                     perfumery               perfumery
#
# [111023 rows x 6 columns]

# %% [markdown]
# ## 재구매율 구하기
# → 전체 고객 중, 특정 카테고리를 한 번 이상 반복 구매한 고객의 비율

# %%
#고객별로 구매한 카테고리 개수 계산
customer_category_counts = df.groupby(['customer_unique_id', 'product_category_name']).size().reset_index(name='purchase_count')
customer_category_counts
# Out:
#                      customer_unique_id product_category_name  purchase_count
# 0      0000366f3b9a7992bf8c76cfdf3221e2        bed_bath_table               1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f         health_beauty               1
# 2      0000f46a3911fa3c0805444483337064            stationery               1
# 3      0000f6ccb0745a6a4b88665a16c9f078             telephony               1
# 4      0004aac84e0df4da2b147fca70cf8255             telephony               1
# ...                                 ...                   ...             ...
# 96443  fffcf5a5ff07b0908bd4e2dbc735a684         health_beauty               2
# 96444  fffea47cd6d3cc0a88bd621562a9d061                  baby               1
# 96445  ffff371b4d645b6ecea244b27531430a                  auto               1
# 96446  ffff5962728ec6157033ef9805bacc48         watches_gifts               1
# 96447  ffffd2657e2aad2907e67c3e9daecbeb             perfumery               1
#
# [96448 rows x 3 columns]

# %%
#구매 횟수가 2회 이상인 경우
repeat_purchases = customer_category_counts[customer_category_counts['purchase_count'] > 1]
repeat_purchases
# Out:
#                      customer_unique_id      product_category_name  \
# 7      00053a61a98854899e70ed204dd4bafe             sports_leisure
# 18     000de6019bb59f34c099a907c151d855             bed_bath_table
# 22     000fbf0473c10fc1ab6f8d2d286ce20c        musical_instruments
# 23     000fbf0473c10fc1ab6f8d2d286ce20c                       toys
# 26     001147e649a7b1afd577e873841632dd                 housewares
# ...                                 ...                        ...
# 96416  ffe96201d466b0e0dc8139850be29d5d  construction_tools_lights
# 96432  fff22793223fe80c97a8fd02ac5c6295                  perfumery
# 96436  fff5eb4918b2bf4b2da476788d42051c     signaling_and_security
# 96438  fff7219c86179ca6441b8f37823ba3d3             bed_bath_table
# 96443  fffcf5a5ff07b0908bd4e2dbc735a684              health_beauty
#
#        purchase_count
# 7                   2
# 18                  2
# 22                  2
# 23                  2
# 26                  2
# ...               ...
# 96416               2
# 96432               3
# 96436               6
# 96438               2
# 96443               2
#
# [10123 rows x 3 columns]

# %%
#재구매 고객 수
repeat_customer_count = repeat_purchases['customer_unique_id'].nunique()
repeat_customer_count
# Out:
# 10037

# %%
#전체 고객 수
total_customers = df['customer_unique_id'].nunique()
total_customers
# Out:
# 96096

# %%
#재구매율
repeat_purchase_rate = repeat_customer_count / total_customers
print(repeat_purchase_rate)
round(repeat_purchase_rate*100,2)
# Out:
# 0.1044476356976357
# 10.44

# %% [markdown]
# ## 카테고리별 재구매율 확인
# ### 목적
# 어떤 제품군이 재구매가 활발한지 분석하여 **전략 수립** 가능 \
# → 반복 구매가 일반적인 경우 **리텐션**, 일회성 구매가 많은 경우 **신규 고객 유입**이 중요\
# → 재구매율이 높은 카테고리는 **충분한 재고 확보** 필요
# ### 방법
# 각 product_category_name별로 고객이 동일한 카테고리를 다시 구매한 비율을 계산

# %%
# 각 카테고리별 고객의 구매 횟수 계산
category_repeat_counts = df.groupby(['product_category_name', 'customer_unique_id']).size().reset_index(name='purchase_count')

# 각 카테고리에서 재구매한 고객 수 계산
category_repurchase = category_repeat_counts[category_repeat_counts['purchase_count'] > 1]
category_repurchase_rate = (
    category_repurchase.groupby('product_category_name')['customer_unique_id'].nunique()
    / category_repeat_counts.groupby('product_category_name')['customer_unique_id'].nunique()
 ) * 100

#float로 변환하여 내림차순 정렬
category_repurchase_rate_numeric = category_repurchase_rate.astype(float).sort_values(ascending=False)

# 데이터프레임으로 변환, Nan은 제외하고 % 기호 보이게 설정
category_repurchase_rate_df = category_repurchase_rate_numeric.to_frame().style.format(lambda x: f"{x:.2f}%" if pd.notna(x) else x)

category_repurchase_rate_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b5a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b5a3_level0_col0" class="col_heading level0 col0" >customer_unique_id</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >product_category_name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b5a3_level0_row0" class="row_heading level0 row0" >home_comfort_2</th>
#       <td id="T_9b5a3_row0_col0" class="data row0 col0" >26.09%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row1" class="row_heading level0 row1" >signaling_and_security</th>
#       <td id="T_9b5a3_row1_col0" class="data row1 col0" >24.46%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row2" class="row_heading level0 row2" >furniture_decor</th>
#       <td id="T_9b5a3_row2_col0" class="data row2 col0" >20.53%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row3" class="row_heading level0 row3" >costruction_tools_garden</th>
#       <td id="T_9b5a3_row3_col0" class="data row3 col0" >19.90%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row4" class="row_heading level0 row4" >office_furniture</th>
#       <td id="T_9b5a3_row4_col0" class="data row4 col0" >18.35%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row5" class="row_heading level0 row5" >furniture_bedroom</th>
#       <td id="T_9b5a3_row5_col0" class="data row5 col0" >17.58%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row6" class="row_heading level0 row6" >cds_dvds_musicals</th>
#       <td id="T_9b5a3_row6_col0" class="data row6 col0" >16.67%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row7" class="row_heading level0 row7" >fashion_male_clothing</th>
#       <td id="T_9b5a3_row7_col0" class="data row7 col0" >16.36%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row8" class="row_heading level0 row8" >garden_tools</th>
#       <td id="T_9b5a3_row8_col0" class="data row8 col0" >16.02%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row9" class="row_heading level0 row9" >bed_bath_table</th>
#       <td id="T_9b5a3_row9_col0" class="data row9 col0" >15.77%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row10" class="row_heading level0 row10" >books_imported</th>
#       <td id="T_9b5a3_row10_col0" class="data row10 col0" >15.38%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row11" class="row_heading level0 row11" >home_construction</th>
#       <td id="T_9b5a3_row11_col0" class="data row11 col0" >15.34%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row12" class="row_heading level0 row12" >air_conditioning</th>
#       <td id="T_9b5a3_row12_col0" class="data row12 col0" >14.74%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row13" class="row_heading level0 row13" >drinks</th>
#       <td id="T_9b5a3_row13_col0" class="data row13 col0" >14.73%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row14" class="row_heading level0 row14" >arts_and_craftmanship</th>
#       <td id="T_9b5a3_row14_col0" class="data row14 col0" >14.29%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row15" class="row_heading level0 row15" >construction_tools_construction</th>
#       <td id="T_9b5a3_row15_col0" class="data row15 col0" >13.98%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row16" class="row_heading level0 row16" >construction_tools_lights</th>
#       <td id="T_9b5a3_row16_col0" class="data row16 col0" >13.93%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row17" class="row_heading level0 row17" >flowers</th>
#       <td id="T_9b5a3_row17_col0" class="data row17 col0" >13.79%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row18" class="row_heading level0 row18" >food_drink</th>
#       <td id="T_9b5a3_row18_col0" class="data row18 col0" >13.78%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row19" class="row_heading level0 row19" >furniture_living_room</th>
#       <td id="T_9b5a3_row19_col0" class="data row19 col0" >13.49%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row20" class="row_heading level0 row20" >industry_commerce_and_business</th>
#       <td id="T_9b5a3_row20_col0" class="data row20 col0" >12.45%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row21" class="row_heading level0 row21" >computers_accessories</th>
#       <td id="T_9b5a3_row21_col0" class="data row21 col0" >12.32%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row22" class="row_heading level0 row22" >housewares</th>
#       <td id="T_9b5a3_row22_col0" class="data row22 col0" >12.21%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row23" class="row_heading level0 row23" >kitchen_dining_laundry_garden_furniture</th>
#       <td id="T_9b5a3_row23_col0" class="data row23 col0" >11.74%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row24" class="row_heading level0 row24" >diapers_and_hygiene</th>
#       <td id="T_9b5a3_row24_col0" class="data row24 col0" >11.54%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row25" class="row_heading level0 row25" >pet_shop</th>
#       <td id="T_9b5a3_row25_col0" class="data row25 col0" >11.49%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row26" class="row_heading level0 row26" >sports_leisure</th>
#       <td id="T_9b5a3_row26_col0" class="data row26 col0" >11.35%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row27" class="row_heading level0 row27" >fixed_telephony</th>
#       <td id="T_9b5a3_row27_col0" class="data row27 col0" >11.06%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row28" class="row_heading level0 row28" >christmas_supplies</th>
#       <td id="T_9b5a3_row28_col0" class="data row28 col0" >10.94%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row29" class="row_heading level0 row29" >agro_industry_and_commerce</th>
#       <td id="T_9b5a3_row29_col0" class="data row29 col0" >10.50%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row30" class="row_heading level0 row30" >party_supplies</th>
#       <td id="T_9b5a3_row30_col0" class="data row30 col0" >10.26%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row31" class="row_heading level0 row31" >fashio_female_clothing</th>
#       <td id="T_9b5a3_row31_col0" class="data row31 col0" >10.26%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row32" class="row_heading level0 row32" >fashion_bags_accessories</th>
#       <td id="T_9b5a3_row32_col0" class="data row32 col0" >9.62%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row33" class="row_heading level0 row33" >computers</th>
#       <td id="T_9b5a3_row33_col0" class="data row33 col0" >9.50%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row34" class="row_heading level0 row34" >construction_tools_safety</th>
#       <td id="T_9b5a3_row34_col0" class="data row34 col0" >9.04%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row35" class="row_heading level0 row35" >food</th>
#       <td id="T_9b5a3_row35_col0" class="data row35 col0" >8.99%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row36" class="row_heading level0 row36" >dvds_blu_ray</th>
#       <td id="T_9b5a3_row36_col0" class="data row36 col0" >8.62%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row37" class="row_heading level0 row37" >health_beauty</th>
#       <td id="T_9b5a3_row37_col0" class="data row37 col0" >8.50%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row38" class="row_heading level0 row38" >fashion_shoes</th>
#       <td id="T_9b5a3_row38_col0" class="data row38 col0" >8.40%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row39" class="row_heading level0 row39" >home_appliances</th>
#       <td id="T_9b5a3_row39_col0" class="data row39 col0" >8.39%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row40" class="row_heading level0 row40" >stationery</th>
#       <td id="T_9b5a3_row40_col0" class="data row40 col0" >7.84%</td>
#     </tr>
#     <tr>
#       <th id="T_9b5a3_level0_row41" class="row_heading level0 row41" >cine_photo</th>
#       <td id="T_9b5a3_row41_col0" class="data row41 col0" >7.69%

# %% [markdown]
# → 최상위권 3가지는 20%대에 그침. 포괄적이며 다량의 카테고리로 나누어져 있기 때문으로 보임.

# %% [markdown]
# ## 고객별 재구매 패턴 확인
# ### 목적
# 1회성 고객과 재구매 고객 구분하여 마케팅 전략 수립하기 위함
# ### 방법
# 한 번만 구매한 고객과 여러 번 구매한 고객을 비교

# %%
# 고객별 총 구매 횟수 계산
customer_total_purchases = df.groupby('customer_unique_id').size().reset_index(name='total_purchases')

# 1회 구매 고객과 반복 구매 고객 분류
one_time_customers = customer_total_purchases[customer_total_purchases['total_purchases'] == 1]
repeat_customers = customer_total_purchases[customer_total_purchases['total_purchases'] > 1]

# 고객 그룹별 평균 구매 수 확인
one_time_avg = one_time_customers['total_purchases'].mean()
repeat_avg = repeat_customers['total_purchases'].mean()

# 결과 출력
print(f"1회 구매 고객 평균 구매 수: {one_time_avg}")
print(f"다회 구매 고객 평균 구매 수: {repeat_avg}")
# Out:
# 1회 구매 고객 평균 구매 수: 1.0
# 다회 구매 고객 평균 구매 수: 2.450732524068648

# %% [markdown]
# → 재구매 고객의 평균 구매수 2.45회로 유의미한 충성 고객 분류 어려움.

# %% [markdown]
# ## 통계적 검증
# 고객이 동일 카테고리를 반복 구매할 확률이 무작위보다 높은지 검정하고자 함.
#
# ### 카이제곱검정
# → 고객의 재구매 여부는 범주형 데이터이므로 두 변수가 서로 독립적인지 확인
# - **변수 1:** 고객이 특정 카테고리를 재구매했는가? (Yes / No)
# - **변수 2:** 제품 카테고리 \
#
#
# - **귀무가설 (H₀):** 고객이 과거에 구매한 카테고리를 다시 구매하는 것은 **랜덤한 현상**이다.
#
#     → 고객이 **이전에 구매한 카테고리와 관계없이** 아무 카테고리나 다시 구매할 가능성이 동일하다.
#
# - **대립가설 (H₁):** 고객은 과거에 구매한 카테고리를 다시 구매할 가능성이 **유의미하게 높다.**
#
#     → 특정 카테고리를 한 번 구매한 고객은 다시 같은 카테고리를 구매하는 경향이 있다.
#
# p-value가 0.05보다 작다면
# **"고객이 과거에 구매한 카테고리를 다시 구매하는 경향이 있다"**고 판단할 수 있다.

# %%
from scipy.stats import chi2_contingency

# 재구매 여부를 나타내는 컬럼 추가
df['repeat_purchase'] = df.duplicated(subset=['customer_unique_id', 'product_category_name'], keep=False)

# 교차표 생성
contingency_table = pd.crosstab(df['repeat_purchase'], df['product_category_name'])

# 카이제곱 검정 실행
chi2, p, dof, expected = chi2_contingency(contingency_table)

# 결과 출력
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")

# 유의 수준 0.05 기준 검정 결과 해석
if p < 0.05:
    print("과거에 구매한 적 있는 카테고리를 다시 구매할 가능성이 유의미하게 높음.")
else:
    print("우연에 가까움.")
# Out:
# Chi-square statistic: 5183.011154437786
# P-value: 0.0
# 과거에 구매한 적 있는 카테고리를 다시 구매할 가능성이 유의미하게 높음.
